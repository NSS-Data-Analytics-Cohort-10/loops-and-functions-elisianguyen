# %% [markdown]
# ## Loops and Functions Practice
#
# In this notebook, you'll get some additional practice working with loops and functions for importing, cleaning, and visualizing data.

# %% [markdown]
# ### Warmup Questions
# ## Loops
#
# Recall that a loop can be used whenever you are repeating the same operation multiple times.
#
# For example,

# %%
print('a')
print('b')
print('c')
print('d')

# %% [markdown]
# can be rewritten to accomplish the same outcome. We just need to recognize that the repeated code is the `print` function and the part that changes is the argument value.

# %%
for letter in ['a','b','c','d']:
    print(letter)

# %% [markdown]
# Recall also that `range` can be helpful when writing for loops if you want to iterate through a set of consecutive numbers.

# %%
for number in range(10):
    print(number)

# %% [markdown]
# **Your Turn:** Write a for loop that prints out the squares of the numbers 1 through 10.

# %%
# Your Code Here
for number in range(1, 11):
    print(number ** 2)

# %% [markdown]
# Now, modify your code so that it prints out the squares of the even integers between 1 and 10.
#
# **Hint:** You can do this either by using conditional logic (if statements) or you might find a different way if you check out the parameters of the range function (https://www.w3schools.com/python/ref_func_range.asp).

# %%
# Your Code Here
for number in range(1, 11):
    if number % 2 == 0:
        square = number ** 2
        print(square)

# %% [markdown]
# ### The Accumulator Pattern
#
# Often when working with loops, you will want to capture the results of each iteration. This is usually done by either using a numeric accumulator or a container like a list to hold the intermediate results.
#
# For example, if we wanted to sum the first 100 positive integers we could do this using the accumulator pattern.

# %%
total_sum = 0 #create accumulator to hold results

for number in range(1, 101): #iterate
    total_sum += number
    
print(f'The total sum is {total_sum}')

# %% [markdown]
# Or, we might want to do a calculation and store the results:

# %%
squares = []
for number in range(1, 10):
    squares.append(number**2) #append stores in empty list

# %%
squares

# %% [markdown]
# **Your Turn:** Find the sum of the squares of all even integers between 2 and 1000.

# %%
total_sum = 0 #create accumulator to hold the results 

for number in range(2, 1001):
    if number % 2 == 0: #if number divided by 2 is equal to 0 then number is even
        square = number ** 2 #if true, square number
        total_sum += square #sum and store in accumulator 
        
print(total_sum)

# %% [markdown]
# ## Functions
#
# When you find yourself repeating the same or very similar code, it could signal that you need a for loop or that you should rewrite your code as a function that can be reused.
#
# Some advantages of using functions are that you don't have to worry about making copy/paste errors and that if you realize that you need to change the logic of your code, you need only update it in one location.
#
# Components of most functions:
# * `def` followed by the name of the function
# * A set of parentheses and the list of function parameters.
# * A body that defines what to do with the inputs.
# * A return statement that indicates what the function outputs.
#
# For example, if we want to calculate the square of a number, we could write a very basic function to accomplish this:

# %%
def square_number(x):
    return x**2

# %% [markdown]
# Once our function is defined, we can call it and pass in inputs:

# %%
square_number(10)

# %%
square_number(-4)

# %% [markdown]
# Our function can also include more complex logic and multiple return statements:

# %%
def absolute_value(x):
    if x >= 0:
        return x
    else:
        return -x

# %%
absolute_value(2)

# %%
absolute_value(-6)

# %% [markdown]
# **Your Turn:** Write a function named `collatz` that will take as input a number. If that number is even, your function should divide it by two and return the result. If the number is odd, it should triple the number and add one and then return the result.
#
# **Hint:** If you want to check if a number is even, you can use the modulus operator. See, for example, https://discuss.codecademy.com/t/how-can-i-check-if-a-number-is-odd/339354.

# %%
# Your Code Here
def collatz(x):
    if x % 2 == 0:
        return x // 2
    else:
        return x * 3 + 1

# %%
print(collatz(48))
print(collatz(2))

# %% [markdown]
# ### Intermediate Questions
#
# For these questions, you'll be working with data from the Lahman baseball database. In order to get this data into Python, we are going to write a query and execute it using the sqlalchemy library.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, text

# %%
database_name = 'lahmans_baseball'    # Fill this in with your lahman database name
connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"
engine = create_engine(connection_string)

# %%
query = """
SELECT *
FROM teams
"""

teams = pd.read_sql(text(query), con = engine)
teams.head(50)
# Out:
#     yearid lgid teamid franchid divid  rank   g  ghome   w   l  ...  dp  \
# 0     1871   NA    BS1      BNA  None     3  31    NaN  20  10  ... NaN
# 1     1871   NA    CH1      CNA  None     2  28    NaN  19   9  ... NaN
# 2     1871   NA    CL1      CFC  None     8  29    NaN  10  19  ... NaN
# 3     1871   NA    FW1      KEK  None     7  19    NaN   7  12  ... NaN
# 4     1871   NA    NY2      NNA  None     5  33    NaN  16  17  ... NaN
# 5     1871   NA    PH1      PNA  None     1  28    NaN  21   7  ... NaN
# 6     1871   NA    RC1      ROK  None     9  25    NaN   4  21  ... NaN
# 7     1871   NA    TRO      TRO  None     6  29    NaN  13  15  ... NaN
# 8     1871   NA    WS3      OLY  None     4  32    NaN  15  15  ... NaN
# 9     1872   NA    BL1      BLC  None     2  58    NaN  35  19  ... NaN
# 10    1872   NA    BR1      ECK  None     9  29    NaN   3  26  ... NaN
# 11    1872   NA    BR2      BRA  None     6  37    NaN   9  28  ... NaN
# 12    1872   NA    BS1      BNA  None     1  48    NaN  39   8  ... NaN
# 13    1872   NA    CL1      CFC  None     7  22    NaN   6  16  ... NaN
# 14    1872   NA    MID      MAN  None     8  24    NaN   5  19  ... NaN
# 15    1872   NA    NY2      NNA  None     3  56    NaN  34  20  ... NaN
# 16    1872   NA    PH1      PNA  None     4  47    NaN  30  14  ... NaN
# 17    1872   NA    TRO      TRO  None     5  25    NaN  15  10  ... NaN
# 18    1872   NA    WS3      OLY  None    10   9    NaN   2   7  ... NaN
# 19    1872   NA    WS4      NAT  None    11  11    NaN   0  11  ... NaN
# 20    1873   NA    BL1      BLC  None     3  57    NaN  34  22  ... NaN
# 21    1873   NA    BL4      MAR  None     9   6    NaN   0   6  ... NaN
# 22    1873   NA    BR2      BRA  None     6  55    NaN  17  37  ... NaN
# 23    1873   NA    BS1      BNA  None     1  60    NaN  43  16  ... NaN
# 24    1873   NA    ELI      RES  None     8  23    NaN   2  21  ... NaN
# 25    1873   NA    NY2      NNA  None     4  53    NaN  29  24  ... NaN
# 26    1873   NA    PH1      PNA  None     5  52    NaN  28  23  ... NaN
# 27    1873   NA    PH2      PWS  None     2  53    NaN  36  17  ... NaN
# 28    1873   NA    WS5      WBL  None     7  39    NaN   8  31  ... NaN
# 29    1874   NA    BL1      BLC  None     8  47    NaN   9  38  ... NaN
# 30    1874   NA    BR2      BRA  None     6  56    NaN  22  33  ... NaN
# 31    1874   NA    BS1      BNA  None     1  71    NaN  52  18  ... NaN
# 32    1874   NA    CH2      CNA  None     5  59    NaN  28  31  ... NaN
# 33    1874   NA    HR1      HNA  None     7  53    NaN  16  37  ... NaN
# 34    1874   NA    NY2      NNA  None     2  65    NaN  42  23  ... NaN
# 35    1874   NA    PH1      PNA  None     3  55    NaN  33  22  ... NaN
# 36    1874   NA    PH2      PWS  None     4  58    NaN  29  29  ... NaN
# 37    1875   NA    BR2      BRA  None    11  44    NaN   2  42  ... NaN
# 38    1875   NA    BS1      BNA  None     1  82    NaN  71   8  ... NaN
# 39    1875   NA    CH2      CNA  None     6  69    NaN  30  37  ... NaN
# 40    1875   NA    HR1      HNA  None     3  86    NaN  54  28  ... NaN
# 41    1875   NA    KEO      WES  None    13  13    NaN   1  12  ... NaN
# 42    1875   NA    NH1      NHV  None     8  47    NaN   7  40  ... NaN
# 43    1875   NA    NY2      NNA  None     6  71    NaN  30  38  ... NaN
# 44    1875   NA    PH1      PNA  None     2  77    NaN  53  20  ... NaN
# 45    1875   NA    PH2      PWS  None     5  70    NaN  37  31  ... NaN
# 46    1875   NA    PH3      CEN  None    11  14    NaN   2  12  ... NaN
# 47    1875   NA    SL1      SLR  None    10  19    NaN   4  15  ... NaN
# 48    1875   NA    SL2      SNA  None     4  70    NaN  39  29  ... NaN
# 49    1875   NA    WS6      WNT  None     9  28    NaN   5  23  ... NaN
#
#        fp                       name                               park  \
# 0   0.838       Boston Red Stockings                South End Grounds I
# 1   0.829    Chicago White Stockings            Union Base-Ball Grounds
# 2   0.814     Cleveland Forest Citys       National Association Grounds
# 3   0.803       Fort Wayne Kekiongas                     Hamilton Field
# 4   0.839           New York Mutuals           Union Grounds (Brooklyn)
# 5   0.845     Philadelphia Athletics           Jefferson Street Grounds
# 6   0.821      Rockford Forest Citys  Agricultural Society Fair Grounds
# 7   0.845             Troy Haymakers                 Haymakers' Grounds
# 8   0.850        Washington Olympics                   Olympics Grounds
# 9   0.829         Baltimore Canaries                     Newington Park
# 10  0.798          Brooklyn Eckfords                      Union Grounds
# 11  0.810         Brooklyn Atlantics                 Capitoline Grounds
# 12  0.874       Boston Red Stockings                South End Grounds I
# 13  0.823     Cleveland Forest Citys       National Association Grounds
# 14  0.806      Middletown Mansfields             Mansfield Club Grounds
# 15  0.867           New York Mutuals           Union Grounds (Brooklyn)
# 16  0.858     Philadelphia Athletics           Jefferson Street Grounds
# 17  0.862             Troy Haymakers                 Haymakers' Grounds
# 18  0.786        Washington Olympics                   Olympics Grounds
# 19  0.765       Washington Nationals                  Nationals Grounds
# 20  0.855         Baltimore Canaries                     Newington Park
# 21  0.768        Baltimore Marylands                     Newington Park
# 22  0.820         Brooklyn Atlantics                      Union Grounds
# 23  0.837       Boston Red Stockings                South End Grounds I
# 24  0.787        Elizabeth Resolutes                Waverly Fairgrounds
# 25  0.821           New York Mutuals           Union Grounds (Brooklyn)
# 26  0.842     Philadelphia Athletics           Jefferson Street Grounds
# 27  0.847        Philadelphia Whites           Jefferson Street Grounds
# 28  0.840       Washington Blue Legs                   Olympics Grounds
# 29  0.819         Baltimore Canaries                     Newington Park
# 30  0.822         Brooklyn Atlantics                      Union Grounds
# 31  0.850       Boston Red Stockings                South End Grounds I
# 32  0.831    Chicago White Stockings                23rd Street Grounds
# 33  0.800        Hartford Dark Blues         Hartford Ball Club Grounds
# 34  0.847           New York Mutuals           Union Grounds (Brooklyn)
# 35  0.839     Philadelphia Athletics           Jefferson Street Grounds
# 36  0.809        Philadelphia Whites           Jefferson Street Grounds
# 37  0.801         Brooklyn Atlantics                      Union Grounds
# 38  0.868       Boston Red Stockings                South End Grounds I
# 39  0.860    Chicago White Stockings                23rd Street Grounds
# 40  0.882        Hartford Dark Blues         Hartford Ball Club Grounds
# 41  0.859            Keokuk Westerns                         Perry Park
# 42  0.816        New Haven Elm Citys                      Hamilton Park
# 43  0.838           New York Mutuals           Union Grounds (Brooklyn)
# 44  0.876     Philadelphia Athletics           Jefferson Street Grounds
# 45  0.846        Philadelphia Whites           Jefferson Street Grounds
# 46  0.769   Philadelphia Centennials                 Centennial Grounds
# 47  0.833    St. Louis Red Stockings         Red Stocking Baseball Park
# 48  0.869  St. Louis Brown Stockings                  Grand Avenue Park
# 49  0.794       Washington Nationals                   Olympics Grounds
#
#     attendance  bpf  ppf  teamidbr  teamidlahman45  teamidretro
# 0          NaN  103   98       BOS             BS1          BS1
# 1          NaN  104  102       CHI             CH1          CH1
# 2          NaN   96  100       CLE             CL1          CL1
# 3          NaN  101  107       KEK             FW1          FW1
# 4          NaN   90   88       NYU             NY2          NY2
# 5          NaN  102   98       ATH             PH1          PH1
# 6          NaN   97   99       ROK             RC1          RC1
# 7          NaN  101  100       TRO             TRO          TRO
# 8          NaN   94   98       OLY             WS3          WS3
# 9          NaN  106  102       BAL             BL1          BL1
# 10         NaN   87   96       ECK             BR1          BR1
# 11         NaN  115  122       BRA             BR2          BR2
# 12         NaN  105  100       BOS             BS1          BS1
# 13         NaN   96  100       CLE             CL1          CL1
# 14         NaN   98  103       MAN             MID          MID
# 15         NaN   93   92       NYU             NY2          NY2
# 16         NaN  102  100       ATH             PH1          PH1
# 17         NaN  101  100       TRO             TRO          TRO
# 18         NaN   94   98       OLY             WS3          WS3
# 19         NaN  129  141       NAT             WS4          WS4
# 20         NaN  101  102       BAL             BL1          BL1
# 21         NaN   77   99       MAR             BL4          BL4
# 22         NaN   90   94       BRA             BR2          BR2
# 23         NaN  106  100       BOS             BS1          BS1
# 24         NaN   92  103       RES             ELI          ELI
# 25         NaN   98   96       NYU             NY2          NY2
# 26         NaN  108  105       ATH             PH1          PH1
# 27         NaN  103  101       PHI             PH2          PH2
# 28         NaN   96  102       WAS             WS5          WS5
# 29         NaN  102  104       BAL             BL1          BL1
# 30         NaN   89   94       BRA             BR2          BR2
# 31         NaN  105   98       BOS             BS1          BS1
# 32         NaN  101  102       CHI             CH2          CH2
# 33         NaN  106  106       HAR             HR1          HR1
# 34         NaN  103  102       NYU             NY2          NY2
# 35         NaN  108  105       ATH             PH1          PH1
# 36         NaN  103  101       PHI             PH2          PH2
# 37         NaN   88   94       BRA             BR2          BR2
# 38         NaN  103   96       BOS             BS1          BS1
# 39         NaN  101  102       CHI             CH2          CH2
# 40         NaN  107  105       HAR             HR1          HR1
# 41         NaN  105  109       WES             KEO          KEO
# 42         NaN   87   93       NHV             NH1          NH1
# 43         NaN   99  100       NYU             NY2          NY2
# 44         NaN  107  106       ATH             PH1          PH1
# 45         NaN  104  102       PHI             PH2          PH2
# 46         NaN   92   98       CEN             PH3          PH3
# 47         NaN   90   98       SLR             SL1          SL1
# 48         NaN   89   86       STL             SL2          SL2
# 49         NaN   96  106       WAS             WS6          WS6
#
# [50 rows x 48 columns]

# %% [markdown]
# Now, you're going to write a series of functions to work with this team data. Note that you can write and execute a SQL query using `read_sql` if you want to check that you're getting the correct results.
#
# Write a function `get_teams` that will take as input a year and which returns the team stats (from the teams table) for the input year.

# %%
def get_teams(year):
    """takes year and returns team stats"""
    return teams[teams["yearid"]==year]

#test
get_teams(1871)
# Out:
#    yearid lgid teamid franchid divid  rank   g  ghome   w   l  ...  dp     fp  \
# 0    1871   NA    BS1      BNA  None     3  31    NaN  20  10  ... NaN  0.838
# 1    1871   NA    CH1      CNA  None     2  28    NaN  19   9  ... NaN  0.829
# 2    1871   NA    CL1      CFC  None     8  29    NaN  10  19  ... NaN  0.814
# 3    1871   NA    FW1      KEK  None     7  19    NaN   7  12  ... NaN  0.803
# 4    1871   NA    NY2      NNA  None     5  33    NaN  16  17  ... NaN  0.839
# 5    1871   NA    PH1      PNA  None     1  28    NaN  21   7  ... NaN  0.845
# 6    1871   NA    RC1      ROK  None     9  25    NaN   4  21  ... NaN  0.821
# 7    1871   NA    TRO      TRO  None     6  29    NaN  13  15  ... NaN  0.845
# 8    1871   NA    WS3      OLY  None     4  32    NaN  15  15  ... NaN  0.850
#
#                       name                               park  attendance  \
# 0     Boston Red Stockings                South End Grounds I         NaN
# 1  Chicago White Stockings            Union Base-Ball Grounds         NaN
# 2   Cleveland Forest Citys       National Association Grounds         NaN
# 3     Fort Wayne Kekiongas                     Hamilton Field         NaN
# 4         New York Mutuals           Union Grounds (Brooklyn)         NaN
# 5   Philadelphia Athletics           Jefferson Street Grounds         NaN
# 6    Rockford Forest Citys  Agricultural Society Fair Grounds         NaN
# 7           Troy Haymakers                 Haymakers' Grounds         NaN
# 8      Washington Olympics                   Olympics Grounds         NaN
#
#    bpf  ppf  teamidbr  teamidlahman45  teamidretro
# 0  103   98       BOS             BS1          BS1
# 1  104  102       CHI             CH1          CH1
# 2   96  100       CLE             CL1          CL1
# 3  101  107       KEK             FW1          FW1
# 4   90   88       NYU             NY2          NY2
# 5  102   98       ATH             PH1          PH1
# 6   97   99       ROK             RC1          RC1
# 7  101  100       TRO             TRO          TRO
# 8   94   98       OLY             WS3          WS3
#
# [9 rows x 48 columns]

# %% [markdown]
# Now, write a function `get_best_teams` that will take as input a `year`, a number `n` (which should default to 5) and a parameter `stat` (which should default to wins "w") and which will return the n teams with the largest value for the selected statistic.
#
# Calling `get_best_teams(year = 2014, n = 3)` should return the Los Angeles Angels, the Baltimore Orioles, and the Washington Nationals.

# %%
#define function w/ parameters and defaults 
def get_best_teams(year, n=5, stat='w'):
    """retrieves best team based of input year as int, number of rows returned 'n', and desired stat. Default n is set to 5 and default stat is set to 'w'"""
    #filter year with parameter 
    filter_year = teams[teams["yearid"]==year]
    #sort by stat column in descending
    return_teams = filter_year.sort_values(stat, ascending=False).head(n)
    #take top n rows by using head
    #best_teams = return_rows.head(n)
    
    #return team names
    print(return_teams["name"])

#test
get_best_teams(year = 2014, n=3)
# Out:
# 2757    Los Angeles Angels of Anaheim
# 2774             Washington Nationals
# 2747                Baltimore Orioles
# Name: name, dtype: object

# %% [markdown]
# Now, modify `get_best_teams` by adding a parameter `ascending` so that you can choose to return either the top or the bottom teams in terms of the selected stat.
#
# Calling `get_best_teams(year=2014, n=3, stat="era", ascending=True)` should return the Washington Nationals, the Seattle Mariners, and the Oakland Athletics.

# %%
#define function w/ parameters and defaults 
def get_best_teams(year, n=5, stat='w', ascending=True):
    """retrieves best team based of input year as int, number of rows returned 'n', and desired stat. Default n is set to 5 and default stat is set to 'w'"""
    
    #filter year with parameter 
    filter_year = teams[teams["yearid"]==year]
    
    #replace False with new parameter added to function
    sort = filter_year.sort_values(stat, ascending=ascending).head(n)
    
    #return team names
    return sort["name"]

#test
get_best_teams(year=2014, n=3, stat="era", ascending=True)
# Out:
# 2774    Washington Nationals
# 2768        Seattle Mariners
# 2764       Oakland Athletics
# Name: name, dtype: object

# %% [markdown]
# Now, modify `get_best_teams` so that you can choose to return just the best teams from one league or the other (using the `lgid` column), but by default does not filter based on league. Do this by adding a `league` parameter with default value of "both".
#
# Calling `get_best_teams(year=2014, n=3, league="AL", ascending = True)` should return the Texas Rangers, the Houston Astros, and the Minnesota Twins.

# %%
def get_best_teams(year, n=5, stat="w", ascending=True, league="both"):

    if league == "both":
        filter_all = teams[teams["yearid"]==year]
        
    else:
        filter_all = teams[(teams["yearid"]==year) & (teams["lgid"]==league)]
    
    sort = filter_all.sort_values(stat, ascending=ascending).head(n)
    
    return sort["name"]

#test 
league_al = get_best_teams(year=2014, n=3, league="both", ascending = True)

print(league_al)
# Out:
# 2772      Texas Rangers
# 2755     Houston Astros
# 2761    Minnesota Twins
# Name: name, dtype: object

# %% [markdown]
# Now, make a function `plot_best_teams` which takes the same parameters as `get_best_teams` but which creates a bar chart displaying the best teams for the selected stats.
#
# Make sure that your plot has a title and is labeled.

# %%
def plot_best_teams(year, n=5, stat="w", ascending=False, league="both"):
    
    if league == "both":
        filter_all = teams[teams["yearid"]==year]
        
    else:
        filter_all = teams[(teams["yearid"]==year) & (teams["lgid"]==league)]
    
    sort = filter_all.sort_values(stat, ascending=ascending).head(n)
    
    #return team names and plot
    plt.barh(sort["name"], sort[stat]) 
    plt.title(f"Top {n} Teams Based on {stat} Stat")
    plt.xlabel(f"{stat}")
    plt.ylabel(f"Top {n} Teams");

#test
plot_best_teams(year=2014, n=3, league="AL", ascending = True)

# %% [markdown]
# Add a `filepath` parameter to `plot_best_teams` which defaults to `None`. If a filepath is given, the function should save the resulting plot to the input filepath. **Hint:** You'll need to use the [`savefig` function](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html).

# %%
def plot_best_teams(year, n=5, stat="w", ascending=False, league="both", filepath=None):
    
    if league == "both":
        filter_all = teams[teams["yearid"]==year]
        
    else:
        filter_all = teams[(teams["yearid"]==year) & (teams["lgid"]==league)]
    
    sort = filter_all.sort_values(stat, ascending=ascending).head(n)
    
    #return team names and plot
    plt.barh(sort["name"], sort[stat]) 
    plt.title(f"Top {n} Teams Based on {stat} Stat")
    plt.xlabel(f"{stat}")
    plt.ylabel(f"Top {n} Teams");
    
    if filepath:
        plt.savefig(filepath)

#test 1 

plot_best_teams(year=2014, n=3, league="AL", ascending = True, filepath='C:/Users/Max-X1/Documents/nss_data_analytics/misc/Images/best_test')

# %% [markdown]
# Finally, utilize a for loop to create an image for each year from 2000 through 2010 which shows the top 10 teams in terms of number of wins. These images should be saved into an `images` folder which appropriate filenames.

# %%
for x in range(2000,2002):
    plot_best_teams(year=x, n=10, stat="w", league="both", filepath="C:/Users/Max-X1/Documents/nss_data_analytics/misc/Images/besttest")

# %% [markdown]
# ### Challenge Questions
#
# If you're able to solve the previous questions, you can give these advanced questions a try.
#
# The [Tennessee Department of Health](https://www.tn.gov/health/health-program-areas/statistics/health-data/death-statistics.html) published data on number of deaths by cause broken down by county.
#
# Start with the data contained in `TN Deaths Malignant Neoplasms - 2018.xlsx`.
#
# If you inspect the file, you'll see that the data is divided up into two tables.
#
# First, let's see how we can read in the lefthand table. We can use the `read_excel` function and point it to columns A - G.

# %%
neoplasms = pd.read_excel(
    '../data/TN Deaths Malignant Neoplasms - 2018.xlsx',
    header=4,
    usecols='A:G'
)

# %%
neoplasms

# %% [markdown]
# Do the following steps to clean up the resulting dataframe:
# * Remove the unneeded rows at the top and bottom
# * Give the columns descriptive names
# * Ensure that the numeric columns are numeric (and have NaNs where there were either *'s or -'s). **Hint:** You could use the pandas `to_numeric` function for this.
#
# Once you have these steps figured out, create a function named `get_deaths_data` that takes as input a `filepath` and string of `usecols` and returns the resulting cleaned up dataframe.

# %%
# Your Code Here

# %% [markdown]
# Now, apply your function to both tables contained in the `TN Deaths Malignant Neoplasms - 2018.xlsx` sheet and concatenate the results together to get a single resulting dataframe.

# %%
# Your Code Here

# %% [markdown]
# We can get a list of all of the filenames contained in the data folder using the `glob` library:

# %%
import glob
filenames = glob.glob('../data/*.xlsx')

filenames

# %% [markdown]
# Your final task is to create a dataframe which has one row per county and one column per cause of death. This column should have the total number of deaths for that cause.

# %%
# Your Code Here
